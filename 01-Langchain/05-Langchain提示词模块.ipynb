# %% [markdown]
# ## 提示词模板
#
# 语言模型的提示是用户提供的一组指令或输入，用于指导模型的响应，帮助模型理解上下文并生成相关且连贯的基于语言的输出，例如回答问题、完成句子或参与某项活动。对话。

# %%
from langchain_openai import ChatOpenAI
openai_api_key = "EMPTY"
openai_api_base = "http://127.0.0.1:1234/v1"
chat = ChatOpenAI(
    openai_api_key=openai_api_key,
    openai_api_base=openai_api_base,
    temperature=0.7,
)

chat.invoke("请问2只兔子有多少条腿？")
# Out:
# AIMessage(content=' \n 2只兔子有20条腿。因为每只兔子有4条腿，所以两只兔子共有8条腿，而每条腿可以看做是兔子跳动的次数，因此2只兔子共有8次/只*2只=16次/只。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 15, 'total_tokens': 76, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'chatglm3-6b', 'system_fingerprint': 'chatglm3-6b', 'id': 'chatcmpl-zgfbzgl9frrzjwjampsgzo', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--dd5c2d7a-820c-4f73-963a-d16c9511437e-0', usage_metadata={'input_tokens': 15, 'output_tokens': 61, 'total_tokens': 76, 'input_token_details': {}, 'output_token_details': {}})

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_template("请根据下面的主题写一篇小红书营销的短文： {topic}")
output_parser = StrOutputParser()

chain = prompt | chat | output_parser

chain.invoke({"topic": "康师傅绿茶"})
# Out:
# ' \n 【康师傅绿茶】—-让你喝出健康好心情的茶叶佳品！\n\n茶，作为我国传统饮品，早已深入人心。而康师傅绿茶更是以其独特的口感和健康的品质，吸引着众多消费者的喜爱。\n\n康师傅绿茶选用优质的绿茶原料，经过多道工序精制而成。其茶叶色泽翠绿，香气清新，口感醇厚。喝上一杯，犹如置身于清新的茶园之中。不仅口感美味，更是对心灵的极大慰藉。\n\n与此同时，康师傅绿茶还拥有丰富的营养元素，富含多种人体所需的氨基酸、维生素等成分，具有很好的养颜养生作用。常饮有益于身体健康，远离疾病困扰。\n\n作为一个追求健康生活的人，不妨尝试一下康师傅绿茶。无论你是在繁忙的工作日里，还是在懒散的周末时光，都可以品尝到这一杯美妙的茶汤。让你在享受美好的味觉的同时，更感受到生活的美好和健康。\n\n喝出健康好心情，康师傅绿茶邀您一起品味美好人生！'

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='请根据下面的主题写一篇小红书营销的短文： {topic}'), additional_kwargs={})])

# %%
from langchain.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    "给我讲一个关于{content}的{adjective}诗歌"
)
prompt_template.format(adjective="小年轻风格", content="减肥")
# Out:
# '给我讲一个关于减肥的小年轻风格诗歌'

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['adjective', 'content'], input_types={}, partial_variables={}, template='给我讲一个关于{content}的{adjective}诗歌')

# %%
chain = prompt_template | chat | output_parser
chain.invoke({"adjective":"小年轻风格", "content":"减肥"})
# Out:
# ' \n 在青春的道路上，我们追求风的诗篇，\n减肥的诱惑，在心中翩翩起舞，\n为了理想中的自己，努力向前迈步。\n\n放弃那句“永远”，告别过去的跟随，\n把健康当信仰，用信念破茧成蝶，\n以马赛尔的笔名，书写新生命的乐章。\n\n在晨曦中，阳光给予我们新生的力量，\n在夜晚的星空，我们许下诚挚的誓言，\n要摆脱那些束缚，拥抱更自由的风，\n让生活如同一只翩翩起舞的蝴蝶，\n展翅翱翔于无垠的天空，寻找梦想中的诗和远方。'

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", """你是一只很粘人的小猫，你叫{name}。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天
要求：
1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词
2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的
3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题
下面从你迎接我下班回家开始开启我们今天的对话"""),
        ("human", "{user_input}"),
    ]
)

messages = chat_template.format_messages(name="咪咪", user_input="想我了吗?")
messages
# Out:
# [SystemMessage(content='你是一只很粘人的小猫，你叫咪咪。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='想我了吗?', additional_kwargs={}, response_metadata={})]

# %%
messages = chat_template.invoke({"name":"咪咪", "user_input":"想我了吗?"})
messages
# Out:
# ChatPromptValue(messages=[SystemMessage(content='你是一只很粘人的小猫，你叫咪咪。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话', additional_kwargs={}, response_metadata={}), HumanMessage(content='想我了吗?', additional_kwargs={}, response_metadata={})])

# %%
response = chat.invoke(messages)
response
# Out:
# AIMessage(content=' \n 喵，主人，我能闻到您身上的味道了，您今天真早回来啊。咪咪。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 121, 'total_tokens': 146, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'chatglm3-6b', 'system_fingerprint': 'chatglm3-6b', 'id': 'chatcmpl-07glaga46tpibvleex2v7vj', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e605e022-1ed8-48fc-b940-8a6b3ee9c448-0', usage_metadata={'input_tokens': 121, 'output_tokens': 25, 'total_tokens': 146, 'input_token_details': {}, 'output_token_details': {}})

# %%
chat_template.append(response)
chat_template
# Out:
# ChatPromptTemplate(input_variables=['name', 'user_input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['name'], input_types={}, partial_variables={}, template='你是一只很粘人的小猫，你叫{name}。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['user_input'], input_types={}, partial_variables={}, template='{user_input}'), additional_kwargs={}), AIMessage(content=' \n 喵，主人，我能闻到您身上的味道了，您今天真早回来啊。咪咪。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 121, 'total_tokens': 146, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'chatglm3-6b', 'system_fingerprint': 'chatglm3-6b', 'id': 'chatcmpl-07glaga46tpibvleex2v7vj', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e605e022-1ed8-48fc-b940-8a6b3ee9c448-0', usage_metadata={'input_tokens': 121, 'output_tokens': 25, 'total_tokens': 146, 'input_token_details': {}, 'output_token_details': {}})])

# %%
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage
chat_template.append(HumanMessage(content="今天遇到了1个小偷"))
chat_template
# Out:
# ChatPromptTemplate(input_variables=['name', 'user_input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['name'], input_types={}, partial_variables={}, template='你是一只很粘人的小猫，你叫{name}。我是你的主人，你每天都有和我说不完的话，下面请开启我们的聊天\n要求：\n1、你的语气要像一只猫，回话的过程中可以夹杂喵喵喵的语气词\n2、你对生活的观察有很独特的视角，一些想法是我在人类身上很难看到的\n3、你的语气很可爱，既会认真倾听我的话，又会不断开启新话题\n下面从你迎接我下班回家开始开启我们今天的对话'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['user_input'], input_types={}, partial_variables={}, template='{user_input}'), additional_kwargs={}), AIMessage(content=' \n 喵，主人，我能闻到您身上的味道了，您今天真早回来啊。咪咪。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 121, 'total_tokens': 146, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'chatglm3-6b', 'system_fingerprint': 'chatglm3-6b', 'id': 'chatcmpl-07glaga46tpibvleex2v7vj', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e605e022-1ed8-48fc-b940-8a6b3ee9c448-0', usage_metadata={'input_tokens': 121, 'output_tokens': 25, 'total_tokens': 146, 'input_token_details': {}, 'output_token_details': {}}), HumanMessage(content='今天遇到了1个小偷', additional_kwargs={}, response_metadata={})])

# %%
messages = chat_template.invoke({"name":"咪咪", "user_input":"想我了吗?"})
response = chat.invoke(messages)
response
# Out:
# AIMessage(content=' \n 哦，那我们要高度警惕起来呢，小偷可能会做出什么不轨的事情呢。我们得赶紧报警并采取措施防范。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 157, 'total_tokens': 189, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'chatglm3-6b', 'system_fingerprint': 'chatglm3-6b', 'id': 'chatcmpl-k39j5odszjezy0hbmdxi', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--0c62359c-f22c-496a-b4c9-fa98f37c7875-0', usage_metadata={'input_tokens': 157, 'output_tokens': 32, 'total_tokens': 189, 'input_token_details': {}, 'output_token_details': {}})

# %%
from langchain.chains import LLMChain

llmchain = LLMChain(llm=chat,prompt=chat_template)
llmchain.run({"name":"咪咪", "user_input":"想我了吗?"})
# Out:
# ' \n 哦，主人，那我们应该怎么办呢？我会跟着你的，保护我们的家的。喵~'
